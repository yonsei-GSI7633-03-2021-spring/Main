# %% [markdown]
# ## 1. 정사각형 그리기 (4점)
# - for 문을 사용하여 주어진 변수 n을 조절 함에 따라 *의 개수를 조절하여 정사각형을 다음과 같이 만들어주세요
# - 아래의 예시는 for문을 사용하지 않고 작성했을때의 예시입니다

# %%
# for 문을 사용하지 않을시
print("n=3")
square = "***\n***\n***"
print(square)
#n이 4일때
print("n=4")
square = "****\n****\n****\n****"
print(square)
# Out:
# n=3
# ***
# ***
# ***
# n=4
# ****
# ****
# ****
# ****

# %%
#for 문을 사용하여 작성해주세요!
n=3
square=''
#TODO

print(square)

# %% [markdown]
# ## 2. 삼각형 그리기 (5점)
# - 1번 문제와 마찬가지로 for 문을 사용하여 삼각형을 그려주세요
# - 아래의 예시는 for문을 사용하지 않고 작성했을때의 예시입니다

# %%
#for 문을 사용하지 않을시의 예시
#n이 3일때
print("n=3")
triangle = "  *\n ***\n*****"
print(triangle)
#n이 4일때
print("n=4")
triangle = "   *\n  ***\n *****\n*******"
print(triangle)
# Out:
# n=3
#   *
#  ***
# *****
# n=4
#    *
#   ***
#  *****
# *******

# %%
### for문을 활용하여, 위와 같이 삼각형을 그리시오
n=3
triangle = ""
#TODO

print(triangle)

# %% [markdown]
# ## 3. 영어 한글 구별  (5점)
# 주어진 문자열이 한글인지 영어인지 구분하는 조건문을 만들어주세요! 문자가 섞여있거나 숫자형 변수는 고려하지 않습니다
# - hint1: 한글은 대소문자 구별이 없습니다.
# - hint2: 정규식을 사용하셔도 좋습니다.
# - hint3: 크기비교를 하셔도 좋습니다.

# %%
is_english = False

data1 = '한글'
data2 = 'english'
data3 = 'ENGLISH'


if data1:#TODO
    is_english = True
else:
    is_english = False
print("{}는 한글입니까?: {}".format(data1, is_english))


if data2:#TODO
    is_english = True
else:
    is_english = False
print("{}는 한글입니까?: {}".format(data2, is_english))


if data3:#TODO
    is_english = True
else:
    is_english = False
print("{}는 한글입니까?: {}".format(data3, is_english))
# Out:
# 한글는 한글입니까?: True
# english는 한글입니까?: True
# ENGLISH는 한글입니까?: True

# %% [markdown]
# ## 4. 데이터 전처리 맛보기

# %% [markdown]
# ### 4-1. 전화번호 포맷 통일시키기  (4점)
# 전화번호 데이터를 입력 받았는데, 입력 받은 포맷이 전부 달라서 사용하기에 어려움이 있습니다. 공백 및 - 없이 전화번호를 재구성해주세요!
# - 올바른 출력: ['01012341234', '01012341234', '01012341234']
# - hint: replace

# %%
phone_numbers =['01012341234', '010-1234-1234', '010 1234 1234']
for index, phone_number in enumerate(phone_numbers):
    #TODO 이곳에서 번호를 변경해주세요!
    phone_numbers[index] = phone_number

print(phone_numbers)
# Out:
# ['01012341234', '010-1234-1234', '010 1234 1234']

# %% [markdown]
# ### 4-2. string으로 이루어진 list를 dictionary로  (4점)
# - 학생들의 시험 점수를 받았는데, list 형태로 되어 있어서, 누가 몇점을 받았는지 바로 확인하기가 어렵습니다. list로 되어 있는 데이터를 dictionary 로 만들어주세요!
# - 올바른 출력: {'흥민': '80', '연경': '95', '연아': '90'}

# %%
scores = ['흥민 80', '연경 95', '연아 90']
scores_dict = {}

for score in scores:
    #TODO 이곳에서 이름과 점수로 각각의 string 분리하고 이름을 key로 점수를 value로 사용해주세요
    scores_dict['흥민'] = 100
    
scores_dict
# Out:
# {'흥민': 100}

# %% [markdown]
# ## 5. 텍스트 파일 다루기

# %% [markdown]
# ### 5.1 scores가 현재 원소가 string인 list로 구현되어 있습니다. 각각의 string을 tuple 형태로 변경해주세요  (7점)
# - hint: for 문을 활용해 각각을 split 명령어로 분리 후 tuple로 변경 (casting)
# - 변경전: ['흥민, 수학, 85\n','연경, 수학, 90\n',..]
# - 변경후: [('흥민,', '수학,', '85'), ('연경,', '수학,', '90'),..]

# %%
scores = []
with open('data.txt','r',encoding='utf-8') as f:
    scores = f.readlines()


for index, score in enumerate(scores):
    #TODO 이곳에서 단순 score변수를 입력하는게 아니라 추가적인 작업을 해주셔야합니다.
    scores[index] = score
scores
# Out:
# ['흥민, 수학, 85\n',
#  '연경, 수학, 90\n',
#  '연아, 수학, 77\n',
#  '세리, 수학, 100\n',
#  '찬호, 수학, 60\n',
#  '현진, 수학, 30\n',
#  '흥민, 영어, 85\n',
#  '연경, 영어, 100\n',
#  '연아, 영어, 81\n',
#  '세리, 영어, 79\n',
#  '찬호, 영어, 98\n',
#  '현진, 영어, 60\n',
#  '흥민, 국어, 73\n',
#  '연경, 국어, 95\n',
#  '연아, 국어, 89\n',
#  '세리, 국어, 65\n',
#  '찬호, 국어, 70\n',
#  '현진, 국어, 38\n']

# %% [markdown]
# ### 5.2 현재 tuple 내에는 쉼표가 포함되어 있습니다. 쉼표를 제거해주세요!  (7점)
# - hint: tuple내의 원소를 각각 접근하여,replace 함수를 사용하여 쉼표를제거
# - 변경전: [('흥민,', '수학,', '85'), ('연경,', '수학,', '90'),..]
# - 변경후: [('흥민', '수학', '85'), ('연경', '수학', '90'),..]

# %%
new_scores = scores.copy()
for index, score in enumerate(scores):
    #TODO 이곳에서 단순 score변수를 입력하는게 아니라 추가적인 작업을 해주셔야합니다.
    new_scores[index] = score
print(new_scores)
# Out:
# ['흥민, 수학, 85\n', '연경, 수학, 90\n', '연아, 수학, 77\n', '세리, 수학, 100\n', '찬호, 수학, 60\n', '현진, 수학, 30\n', '흥민, 영어, 85\n', '연경, 영어, 100\n', '연아, 영어, 81\n', '세리, 영어, 79\n', '찬호, 영어, 98\n', '현진, 영어, 60\n', '흥민, 국어, 73\n', '연경, 국어, 95\n', '연아, 국어, 89\n', '세리, 국어, 65\n', '찬호, 국어, 70\n', '현진, 국어, 38\n']

# %% [markdown]
# ### 5.3 흥민이의 총점은 몇 점일까요?  (5점)

# %%
### 5.3 흥민이의 총점은 몇 점일까요?
heungmin_score = 0
for index, score in enumerate(scores):
    #TODO 이곳에서 if 문을 사용하여 흥민이의 점수만 골라주세요!
    heungmin_score += 0
heungmin_score
# Out:
# 0
